# %%
# Dependencies
import requests
from config import api_key
from pprint import pprint

url = "https://api.nytimes.com/svc/search/v2/articlesearch.json?"

#Build query url


# Store a search term

search = "zebras"

# Search for articles published between a begin and end date

search_url = url + "q=" +search +"&api-key=" + api_key

params = {
    'q':search,
    'api-key':api_key
}

articles = requests.get(url,params = params).json()
#search_url
date_range = "&facet_field=day_of_week&begin_date=20211201&end_date=20211220"
# Search for articles published between a begin and end date

#search_url = url + "q=" + search + date_range + "&api-key=" + api_key

# Build url
print(search_url)
# Out:
# https://api.nytimes.com/svc/search/v2/articlesearch.json?q=zebras&api-key=08cddKYMRascAS3AuXuQjNUU6jwlCIbY

# %%
# Retrieve articles
#article_results = requests.get(search_url).json()
pprint(articles)
articles_list = [article for article in articles["response"]["docs"]]
# Out:
# {'copyright': 'Copyright (c) 2021 The New York Times Company. All Rights '
#               'Reserved.',
#  'response': {'docs': [{'_id': 'nyt://article/f1e99005-1524-55cb-9661-8db73543bc18',
#                         'abstract': 'The two zebras had escaped with another, '
#                                     'which was later found dead, from a '
#                                     'suburban farm, delighting residents and '
#                                     'evading attempts to capture them, the '
#                                     'authorities said.',
#                         'byline': {'organization': None,
#                                    'original': 'By Alyssa Lukpat',
#                                    'person': [{'firstname': 'Alyssa',
#                                                'lastname': 'Lukpat',
#                                                'middlename': None,
#                                                'organization': '',
# ...

# %%
print("YOur reaading list")
for article in articles_list:
    print(f'*{articles["web_url"]}')
# Out:
# YOur reaading list
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_12884/3425619568.py in <module>
#       1 print("YOur reaading list")
#       2 for article in articles_list:
# ----> 3     print(f'*{articles["web_url"]}')
#
# KeyError: 'web_url'

# %%
article_results[2][1][8][10]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_12884/1421650239.py in <module>
# ----> 1 article_results[2][1][8][10]
#
# KeyError: 2

# %%
# BONUS: How would we get 30 results? 
# HINT: Look up the page query param
