# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from citipy import citipy
import requests
from config import weather_api_key
from datetime import datetime
import time
from pprint import pprint

# %%
#Create a set of random latitude and longitude combinations
lats = np.random.uniform(-90.000, 90.000, size = 2000)
lngs = np.random.uniform(-180, 180, size = 2000)
lat_lngs = zip(lats,lngs)
lat_lngs

#Add the latitudes and longitudes to a list
coordinates = list(lat_lngs)
#coordinates

# %%
#Create a list for holding the cities
cities = []
#Identify the nearest city for each coordinate set 
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0],coordinate[1]).city_name
    
    #If city is unique, add it to the city list
    if city not in cities:
        cities.append(city)
        
#Print the city count to confirm sufficient count
len(cities)
# Out:
# 746

# %%
#Starting URL for Weather Map API call
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID="+weather_api_key

#Create an empty list to hold the weather data
city_data = []

#Print the beginning of the logging
print("Beginning Data Retrieval   ")
print("-------------------------")

#Create counters
record_count = 1
set_count = 1


#Loop through the cities and build the city url
for i, city in enumerate(cities):
    
    
    
    #Group cities in sets of 50 for logging purposes
    #if i has no remainder when divided by 50, which means we have completed a set of 50, 
    #then increment main counter and increment set counter
    #so this if is executed after the 50th, 100th, etc pass, this is when we sleep for a minute
    if (i % 50 == 0 and i >= 50):  # % is the operator for modular arithmetic
        set_count += 1
        record_count = 1
        time.sleep(60)

    #Create an endpoint url with each city
    city_url = url + "&q=" + city.replace(" ","+")

    #Log the URL, record, and set numbers and the city
    print(f"Processing Record {record_count} of Set {set_count} | {city}")

    #Add one to the record count
    record_count += 1
    
    try:
        #Parse the JSON and retrieve data
        city_weather = requests.get(city_url).json()
        #Parse out the needed data
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_description = city_weather["weather"][0]["description"]
        #Convert the time to ISO standard
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M%S')
        #append the data into the city_data list
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Weather Description": city_description,
                          "Date": city_date})
        
    #if an error is experienced, skip the city    
    except:
        print("City not found. Skipping...")
        pass
    
#Indicate that the Data Loading is complete
print("-------------------------")
print("Data Retrieval Complete")
print("-------------------------")
# Out:
# Beginning Data Retrieval
# -------------------------
# Processing Record 1 of Set 1 | smithers
# Processing Record 2 of Set 1 | kapaa
# Processing Record 3 of Set 1 | warri
# Processing Record 4 of Set 1 | erenhot
# Processing Record 5 of Set 1 | saint-paul
# Processing Record 6 of Set 1 | atuona
# Processing Record 7 of Set 1 | mys shmidta
# City not found. Skipping...
# Processing Record 8 of Set 1 | ancud
# Processing Record 9 of Set 1 | jutai
# Processing Record 10 of Set 1 | new norfolk
# Processing Record 11 of Set 1 | victoria
# Processing Record 12 of Set 1 | aklavik
# Processing Record 13 of Set 1 | waipawa
# Processing Record 14 of Set 1 | krasnyy chikoy
# Processing Record 15 of Set 1 | saleaula
# City not found. Skipping...
# Processing Record 16 of Set 1 | chifeng
# Processing Record 17 of Set 1 | wajir
# Processing Record 18 of Set 1 | chokurdakh
# Processing Record 19 of Set 1 | hobart
# Processing Record 20 of Set 1 | qaanaaq
# Processing Record 21 of Set 1 | itarema
# Processing Record 22 of Set 1 | albany
# Processing Record 23 of Set 1 | cabo san lucas
# Processing Record 24 of Set 1 | hambantota
# Processing Record 25 of Set 1 | demba
# Processing Record 26 of Set 1 | east london
# Processing Record 27 of Set 1 | xining
# Processing Record 28 of Set 1 | alofi
# Processing Record 29 of Set 1 | pasni
# Processing Record 30 of Set 1 | mataura
# Processing Record 31 of Set 1 | el silencio
# Processing Record 32 of Set 1 | padang
# Processing Record 33 of Set 1 | ishigaki
# Processing Record 34 of Set 1 | ponta do sol
# Processing Record 35 of Set 1 | amderma
# City not found. Skipping...
# Processing Record 36 of Set 1 | puerto ayora
# Processing Record 37 of Set 1 | tasiilaq
# Processing Record 38 of Set 1 | lima
# Processing Record 39 of Set 1 | rikitea
# Processing Record 40 of Set 1 | castro
# Processing Record 41 of Set 1 | punta arenas
# Processing Record 42 of Set 1 | busselton
# Processing Record 43 of Set 1 | chern
# Processing Record 44 of Set 1 | ushuaia
# Processing Record 45 of Set 1 | tsihombe
# City not found. Skipping...
# Processing Record 46 of Set 1 | thompson
# Processing Record 47 of Set 1 | karratha
# Processing Record 48 of Set 1 | umzimvubu
# City not found. Skipping...
# Processing Record 49 of Set 1 | gilbues
# Processing Record 50 of Set 1 | maceio
# Processing Record 1 of Set 2 | paradwip
# City not found. Skipping...
# Processing Record 2 of Set 2 | murgab
# Processing Record 3 of Set 2 | khatanga
# Processing Record 4 of Set 2 | daru
# Processing Record 5 of Set 2 | kamenskoye
# City not found. Skipping...
# Processing Record 6 of Set 2 | bluff
# Processing Record 7 of Set 2 | vung tau
# Processing Record 8 of Set 2 | saint paul
# Processing Record 9 of Set 2 | bolungarvik
# City not found. Skipping...
# Processing Record 10 of Set 2 | peleduy
# Processing Record 11 of Set 2 | hermanus
# Processing Record 12 of Set 2 | fortuna
# Processing Record 13 of Set 2 | jamestown
# Processing Record 14 of Set 2 | hofn
# Processing Record 15 of Set 2 | bayan
# Processing Record 16 of Set 2 | port elizabeth
# Processing Record 17 of Set 2 | akdagmadeni
# Processing Record 18 of Set 2 | pisco
# Processing Record 19 of Set 2 | iqaluit
# Processing Record 20 of Set 2 | morant bay
# Processing Record 21 of Set 2 | mahebourg
# Processing Record 22 of Set 2 | avarua
# Processing Record 23 of Set 2 | bredasdorp
# Processing Record 24 of Set 2 | meulaboh
# Processing Record 25 of Set 2 | orange cove
# Processing Record 26 of Set 2 | faanui
# Processing Record 27 of Set 2 | torbay
# Processing Record 28 of Set 2 | chara
# Processing Record 29 of Set 2 | la crosse
# Processing Record 30 of Set 2 | sentyabrskiy
# City not found. Skipping...
# Processing Record 31 of Set 2 | thinadhoo
# Processing Record 32 of Set 2 | atocha
# Processing Record 33 of Set 2 | cape town
# Processing Record 34 of Set 2 | pallattur
# Processing Record 35 of Set 2 | anadyr
# Processing Record 36 of Set 2 | pierre
# Processing Record 37 of Set 2 | vardo
# Processing Record 38 of Set 2 | bay roberts
# Processing Record 39 of Set 2 | bazaliya
# Processing Record 40 of Set 2 | luderitz
# Processing Record 41 of Set 2 | imbituba
# Processing Record 42 of Set 2 | mar del plata
# Processing Record 43 of Set 2 | tuktoyaktuk
# Processing Record 44 of Set 2 | taolanaro
# City not found. Skipping...
# Processing Record 45 of Set 2 | hilo
# Processing Record 46 of Set 2 | anloga
# Processing Record 47 of Set 2 | zheleznodorozhnyy
# Processing Record 48 of Set 2 | pringsewu
# Processing Record 49 of Set 2 | blankenburg
# Processing Record 50 of Set 2 | georgetown
# Processing Record 1 of Set 3 | yerofey pavlovich
# Processing Record 2 of Set 3 | maniitsoq
# Processing Record 3 of Set 3 | port alfred
# Processing Record 4 of Set 3 | bubaque
# Processing Record 5 of Set 3 | matara
# Processing Record 6 of Set 3 | anamur
# Processing Record 7 of Set 3 | zabid
# Processing Record 8 of Set 3 | airai
# Processing Record 9 of Set 3 | saskylakh
# Processing Record 10 of Set 3 | upernavik
# Processing Record 11 of Set 3 | kruisfontein
# Processing Record 12 of Set 3 | saldanha
# Processing Record 13 of Set 3 | maksatikha
# Processing Record 14 of Set 3 | vaini
# Processing Record 15 of Set 3 | souillac
# Processing Record 16 of Set 3 | norman wells
# Processing Record 17 of Set 3 | kamenka
# Processing Record 18 of Set 3 | agadez
# Processing Record 19 of Set 3 | hasaki
# Processing Record 20 of Set 3 | tarakan
# Processing Record 21 of Set 3 | coihaique
# Processing Record 22 of Set 3 | bonavista
# Processing Record 23 of Set 3 | port hedland
# Processing Record 24 of Set 3 | mlonggo
# Processing Record 25 of Set 3 | husavik
# Processing Record 26 of Set 3 | smalininkai
# Processing Record 27 of Set 3 | attawapiskat
# City not found. Skipping...
# Processing Record 28 of Set 3 | belushya guba
# City not found. Skipping...
# Processing Record 29 of Set 3 | alihe
# Processing Record 30 of Set 3 | dingle
# Processing Record 31 of Set 3 | coquimbo
# Processing Record 32 of Set 3 | samusu
# City not found. Skipping...
# Processing Record 33 of Set 3 | severo-kurilsk
# Processing Record 34 of Set 3 | ribeira grande
# Processing Record 35 of Set 3 | katastarion
# Processing Record 36 of Set 3 | ajdabiya
# Processing Record 37 of Set 3 | dzhusaly
# City not found. Skipping...
# Processing Record 38 of Set 3 | warqla
# City not found. Skipping...
# Processing Record 39 of Set 3 | umm lajj
# Processing Record 40 of Set 3 | tuatapere
# Processing Record 41 of Set 3 | muisne
# Processing Record 42 of Set 3 | te anau
# Processing Record 43 of Set 3 | rehoboth
# Processing Record 44 of Set 3 | salalah
# Processing Record 45 of Set 3 | tasbuget
# City not found. Skipping...
# Processing Record 46 of Set 3 | russell
# Processing Record 47 of Set 3 | butterworth
# Processing Record 48 of Set 3 | fomboni
# Processing Record 49 of Set 3 | butaritari
# Processing Record 50 of Set 3 | northam
# Processing Record 1 of Set 4 | ostrovnoy
# Processing Record 2 of Set 4 | lagoa
# Processing Record 3 of Set 4 | tabiauea
# City not found. Skipping...
# Processing Record 4 of Set 4 | abu samrah
# Processing Record 5 of Set 4 | touros
# Processing Record 6 of Set 4 | luau
# Processing Record 7 of Set 4 | uddevalla
# Processing Record 8 of Set 4 | bratsk
# Processing Record 9 of Set 4 | baoning
# Processing Record 10 of Set 4 | san jose
# Processing Record 11 of Set 4 | tilichiki
# Processing Record 12 of Set 4 | umm ruwabah
# City not found. Skipping...
# Processing Record 13 of Set 4 | bengkulu
# Processing Record 14 of Set 4 | seoul
# Processing Record 15 of Set 4 | pacific grove
# Processing Record 16 of Set 4 | yellowknife
# Processing Record 17 of Set 4 | birobidzhan
# Processing Record 18 of Set 4 | springfield
# Processing Record 19 of Set 4 | siverek
# Processing Record 20 of Set 4 | ardabil
# Processing Record 21 of Set 4 | palana
# Processing Record 22 of Set 4 | pevek
# Processing Record 23 of Set 4 | lakes entrance
# Processing Record 24 of Set 4 | banda aceh
# Processing Record 25 of Set 4 | perevolotskiy
# Processing Record 26 of Set 4 | moose factory
# Processing Record 27 of Set 4 | arraial do cabo
# Processing Record 28 of Set 4 | longyearbyen
# Processing Record 29 of Set 4 | doctor pedro p. pena
# City not found. Skipping...
# Processing Record 30 of Set 4 | solhan
# Processing Record 31 of Set 4 | the valley
# Processing Record 32 of Set 4 | fairbanks
# Processing Record 33 of Set 4 | starkville
# Processing Record 34 of Set 4 | berlevag
# Processing Record 35 of Set 4 | bethel
# Processing Record 36 of Set 4 | nizhneyansk
# City not found. Skipping...
# Processing Record 37 of Set 4 | cayenne
# Processing Record 38 of Set 4 | korla
# Processing Record 39 of Set 4 | ayan
# Processing Record 40 of Set 4 | kavieng
# Processing Record 41 of Set 4 | pokrovsk
# Processing Record 42 of Set 4 | provideniya
# Processing Record 43 of Set 4 | louisbourg
# City not found. Skipping...
# Processing Record 44 of Set 4 | dhidhdhoo
# Processing Record 45 of Set 4 | bom despacho
# Processing Record 46 of Set 4 | poggibonsi
# Processing Record 47 of Set 4 | talnakh
# Processing Record 48 of Set 4 | yurya
# City not found. Skipping...
# Processing Record 49 of Set 4 | igrim
# Processing Record 50 of Set 4 | waingapu
# Processing Record 1 of Set 5 | teknaf
# Processing Record 2 of Set 5 | chachapoyas
# Processing Record 3 of Set 5 | caravelas
# Processing Record 4 of Set 5 | diamantino
# Processing Record 5 of Set 5 | toliary
# City not found. Skipping...
# Processing Record 6 of Set 5 | yaan
# Processing Record 7 of Set 5 | dawson creek
# Processing Record 8 of Set 5 | lumphat
# Processing Record 9 of Set 5 | lorengau
# Processing Record 10 of Set 5 | carnarvon
# Processing Record 11 of Set 5 | blagoyevo
# Processing Record 12 of Set 5 | ruteng
# Processing Record 13 of Set 5 | severomorsk
# Processing Record 14 of Set 5 | polonnaruwa
# Processing Record 15 of Set 5 | sitka
# Processing Record 16 of Set 5 | cherskiy
# Processing Record 17 of Set 5 | henties bay
# Processing Record 18 of Set 5 | geraldton
# Processing Record 19 of Set 5 | nong han
# Processing Record 20 of Set 5 | komsomolskiy
# Processing Record 21 of Set 5 | jeremie
# Processing Record 22 of Set 5 | kaele
# Processing Record 23 of Set 5 | shangqiu
# Processing Record 24 of Set 5 | dikson
# Processing Record 25 of Set 5 | messina
# Processing Record 26 of Set 5 | neiafu
# Processing Record 27 of Set 5 | nakusp
# Processing Record 28 of Set 5 | ketchikan
# Processing Record 29 of Set 5 | barentsburg
# City not found. Skipping...
# Processing Record 30 of Set 5 | urcos
# Processing Record 31 of Set 5 | ron
# Processing Record 32 of Set 5 | quarai
# Processing Record 33 of Set 5 | neyshabur
# Processing Record 34 of Set 5 | porto novo
# Processing Record 35 of Set 5 | adrar
# Processing Record 36 of Set 5 | chuy
# Processing Record 37 of Set 5 | boyolangu
# Processing Record 38 of Set 5 | severodvinsk
# Processing Record 39 of Set 5 | elbistan
# Processing Record 40 of Set 5 | mvuma
# Processing Record 41 of Set 5 | kodiak
# Processing Record 42 of Set 5 | san patricio
# Processing Record 43 of Set 5 | kurchum
# Processing Record 44 of Set 5 | dalbeattie
# Processing Record 45 of Set 5 | jalu
# Processing Record 46 of Set 5 | khandbari
# Processing Record 47 of Set 5 | hirara
# Processing Record 48 of Set 5 | arlit
# Processing Record 49 of Set 5 | petropavlovsk-kamchatskiy
# Processing Record 50 of Set 5 | sambava
# Processing Record 1 of Set 6 | nome
# Processing Record 2 of Set 6 | flagstaff
# Processing Record 3 of Set 6 | barrow
# Processing Record 4 of Set 6 | ossora
# Processing Record 5 of Set 6 | lakatoro
# Processing Record 6 of Set 6 | fort nelson
# Processing Record 7 of Set 6 | puerto carreno
# Processing Record 8 of Set 6 | garden city
# Processing Record 9 of Set 6 | taywarah
# Processing Record 10 of Set 6 | dudinka
# Processing Record 11 of Set 6 | palabuhanratu
# City not found. Skipping...
# Processing Record 12 of Set 6 | marcona
# City not found. Skipping...
# Processing Record 13 of Set 6 | gambiran
# Processing Record 14 of Set 6 | necochea
# Processing Record 15 of Set 6 | lanjaghbyur
# Processing Record 16 of Set 6 | bulgan
# Processing Record 17 of Set 6 | huilong
# Processing Record 18 of Set 6 | colares
# Processing Record 19 of Set 6 | delijan
# Processing Record 20 of Set 6 | olafsvik
# Processing Record 21 of Set 6 | slawno
# Processing Record 22 of Set 6 | quatre cocos
# Processing Record 23 of Set 6 | plastun
# Processing Record 24 of Set 6 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 25 of Set 6 | tateyama
# Processing Record 26 of Set 6 | hastings
# Processing Record 27 of Set 6 | marienburg
# Processing Record 28 of Set 6 | invermere
# Processing Record 29 of Set 6 | vaitupu
# City not found. Skipping...
# Processing Record 30 of Set 6 | chilca
# Processing Record 31 of Set 6 | yerbogachen
# Processing Record 32 of Set 6 | laredo
# Processing Record 33 of Set 6 | lockhart
# Processing Record 34 of Set 6 | binga
# Processing Record 35 of Set 6 | wasilla
# Processing Record 36 of Set 6 | hithadhoo
# Processing Record 37 of Set 6 | nanortalik
# Processing Record 38 of Set 6 | constitucion
# Processing Record 39 of Set 6 | rancho palos verdes
# Processing Record 40 of Set 6 | palmer
# Processing Record 41 of Set 6 | laguna
# Processing Record 42 of Set 6 | dalvik
# Processing Record 43 of Set 6 | sharan
# Processing Record 44 of Set 6 | altay
# Processing Record 45 of Set 6 | southbridge
# Processing Record 46 of Set 6 | egvekinot
# Processing Record 47 of Set 6 | bilibino
# Processing Record 48 of Set 6 | neftcala
# Processing Record 49 of Set 6 | flinders
# Processing Record 50 of Set 6 | kalemie
# Processing Record 1 of Set 7 | porec
# Processing Record 2 of Set 7 | saint george
# Processing Record 3 of Set 7 | duluth
# Processing Record 4 of Set 7 | balkanabat
# Processing Record 5 of Set 7 | grindavik
# Processing Record 6 of Set 7 | svetlyy
# Processing Record 7 of Set 7 | biu
# Processing Record 8 of Set 7 | batagay-alyta
# Processing Record 9 of Set 7 | djambala
# Processing Record 10 of Set 7 | tumannyy
# City not found. Skipping...
# Processing Record 11 of Set 7 | lompoc
# Processing Record 12 of Set 7 | toora-khem
# Processing Record 13 of Set 7 | le port
# Processing Record 14 of Set 7 | sao felix do xingu
# Processing Record 15 of Set 7 | marsa matruh
# Processing Record 16 of Set 7 | rudnya
# Processing Record 17 of Set 7 | xalpatlahuac
# Processing Record 18 of Set 7 | vao
# Processing Record 19 of Set 7 | vrangel
# Processing Record 20 of Set 7 | vacaville
# Processing Record 21 of Set 7 | chanderi
# Processing Record 22 of Set 7 | jumla
# Processing Record 23 of Set 7 | kharan
# Processing Record 24 of Set 7 | murdochville
# Processing Record 25 of Set 7 | cidreira
# Processing Record 26 of Set 7 | rabo de peixe
# Processing Record 27 of Set 7 | bria
# Processing Record 28 of Set 7 | alice springs
# Processing Record 29 of Set 7 | klaksvik
# Processing Record 30 of Set 7 | haines junction
# Processing Record 31 of Set 7 | baherden
# Processing Record 32 of Set 7 | lasa
# Processing Record 33 of Set 7 | kahului
# Processing Record 34 of Set 7 | jiangyou
# Processing Record 35 of Set 7 | longavi
# Processing Record 36 of Set 7 | hamilton
# Processing Record 37 of Set 7 | ericeira
# Processing Record 38 of Set 7 | batemans bay
# Processing Record 39 of Set 7 | kuusamo
# Processing Record 40 of Set 7 | parainen
# Processing Record 41 of Set 7 | bridlington
# Processing Record 42 of Set 7 | katsuura
# Processing Record 43 of Set 7 | zhuanghe
# Processing Record 44 of Set 7 | baraut
# Processing Record 45 of Set 7 | hihifo
# City not found. Skipping...
# Processing Record 46 of Set 7 | sioux lookout
# Processing Record 47 of Set 7 | grand river south east
# City not found. Skipping...
# Processing Record 48 of Set 7 | tonj
# Processing Record 49 of Set 7 | taltal
# Processing Record 50 of Set 7 | iralaya
# Processing Record 1 of Set 8 | aksarka
# Processing Record 2 of Set 8 | pochutla
# Processing Record 3 of Set 8 | najran
# Processing Record 4 of Set 8 | bathsheba
# Processing Record 5 of Set 8 | kholm
# Processing Record 6 of Set 8 | sinnamary
# Processing Record 7 of Set 8 | kongsvinger
# Processing Record 8 of Set 8 | gerash
# Processing Record 9 of Set 8 | moree
# Processing Record 10 of Set 8 | namibe
# Processing Record 11 of Set 8 | tra vinh
# Processing Record 12 of Set 8 | asau
# Processing Record 13 of Set 8 | hailar
# Processing Record 14 of Set 8 | makakilo city
# Processing Record 15 of Set 8 | guhagar
# Processing Record 16 of Set 8 | pacifica
# Processing Record 17 of Set 8 | rio gallegos
# Processing Record 18 of Set 8 | sterling
# Processing Record 19 of Set 8 | timra
# Processing Record 20 of Set 8 | tiksi
# Processing Record 21 of Set 8 | sao joao da barra
# Processing Record 22 of Set 8 | golden
# Processing Record 23 of Set 8 | mackenzie
# Processing Record 24 of Set 8 | chernyshevskiy
# Processing Record 25 of Set 8 | santa cruz
# Processing Record 26 of Set 8 | george
# Processing Record 27 of Set 8 | cam ranh
# Processing Record 28 of Set 8 | kaitangata
# Processing Record 29 of Set 8 | saint-francois
# Processing Record 30 of Set 8 | kalocsa
# Processing Record 31 of Set 8 | skjervoy
# Processing Record 32 of Set 8 | nelson bay
# Processing Record 33 of Set 8 | bakchar
# Processing Record 34 of Set 8 | honiara
# Processing Record 35 of Set 8 | leningradskiy
# Processing Record 36 of Set 8 | khorixas
# Processing Record 37 of Set 8 | namangan
# Processing Record 38 of Set 8 | shenjiamen
# Processing Record 39 of Set 8 | nadym
# Processing Record 40 of Set 8 | broome
# Processing Record 41 of Set 8 | liepaja
# Processing Record 42 of Set 8 | bilma
# Processing Record 43 of Set 8 | amahai
# Processing Record 44 of Set 8 | maryville
# Processing Record 45 of Set 8 | san policarpo
# Processing Record 46 of Set 8 | zhezkazgan
# Processing Record 47 of Set 8 | sokolo
# Processing Record 48 of Set 8 | los llanos de aridane
# Processing Record 49 of Set 8 | manokwari
# Processing Record 50 of Set 8 | yulara
# Processing Record 1 of Set 9 | alyangula
# Processing Record 2 of Set 9 | banyo
# Processing Record 3 of Set 9 | phan thiet
# Processing Record 4 of Set 9 | huarmey
# Processing Record 5 of Set 9 | arman
# Processing Record 6 of Set 9 | sorong
# Processing Record 7 of Set 9 | wukari
# Processing Record 8 of Set 9 | srednekolymsk
# Processing Record 9 of Set 9 | vostok
# Processing Record 10 of Set 9 | seminole
# Processing Record 11 of Set 9 | bull savanna
# Processing Record 12 of Set 9 | ugoofaaru
# Processing Record 13 of Set 9 | saint-philippe
# Processing Record 14 of Set 9 | portland
# Processing Record 15 of Set 9 | itaperucu
# Processing Record 16 of Set 9 | ogulin
# Processing Record 17 of Set 9 | tezu
# Processing Record 18 of Set 9 | bend
# Processing Record 19 of Set 9 | ayia galini
# Processing Record 20 of Set 9 | inirida
# Processing Record 21 of Set 9 | baependi
# Processing Record 22 of Set 9 | gilgit
# Processing Record 23 of Set 9 | boa vista
# Processing Record 24 of Set 9 | doha
# Processing Record 25 of Set 9 | birjand
# Processing Record 26 of Set 9 | maarianhamina
# Processing Record 27 of Set 9 | narsaq
# Processing Record 28 of Set 9 | la ronge
# Processing Record 29 of Set 9 | aykhal
# Processing Record 30 of Set 9 | baykit
# Processing Record 31 of Set 9 | paka
# Processing Record 32 of Set 9 | cabedelo
# Processing Record 33 of Set 9 | zaraza
# Processing Record 34 of Set 9 | abha
# Processing Record 35 of Set 9 | jacareacanga
# Processing Record 36 of Set 9 | nchelenge
# Processing Record 37 of Set 9 | akureyri
# Processing Record 38 of Set 9 | sao pedro do sul
# Processing Record 39 of Set 9 | ippy
# Processing Record 40 of Set 9 | naze
# Processing Record 41 of Set 9 | kloulklubed
# Processing Record 42 of Set 9 | lensk
# Processing Record 43 of Set 9 | gobabis
# Processing Record 44 of Set 9 | karamea
# City not found. Skipping...
# Processing Record 45 of Set 9 | wewak
# Processing Record 46 of Set 9 | leonidovo
# Processing Record 47 of Set 9 | addis zemen
# City not found. Skipping...
# Processing Record 48 of Set 9 | sao filipe
# Processing Record 49 of Set 9 | chaozhou
# Processing Record 50 of Set 9 | lumeje
# Processing Record 1 of Set 10 | misratah
# Processing Record 2 of Set 10 | poum
# Processing Record 3 of Set 10 | atar
# Processing Record 4 of Set 10 | borovoy
# Processing Record 5 of Set 10 | tessalit
# Processing Record 6 of Set 10 | mahajanga
# Processing Record 7 of Set 10 | creel
# Processing Record 8 of Set 10 | kalanchak
# Processing Record 9 of Set 10 | griffith
# Processing Record 10 of Set 10 | mamburao
# Processing Record 11 of Set 10 | dunedin
# Processing Record 12 of Set 10 | hami
# Processing Record 13 of Set 10 | bambous virieux
# Processing Record 14 of Set 10 | fecamp
# Processing Record 15 of Set 10 | qaqortoq
# Processing Record 16 of Set 10 | gnjilane
# Processing Record 17 of Set 10 | ampanihy
# Processing Record 18 of Set 10 | dibrugarh
# Processing Record 19 of Set 10 | bandarbeyla
# Processing Record 20 of Set 10 | gizo
# Processing Record 21 of Set 10 | odweyne
# Processing Record 22 of Set 10 | kavaratti
# Processing Record 23 of Set 10 | sangar
# Processing Record 24 of Set 10 | srimushnam
# Processing Record 25 of Set 10 | siocon
# Processing Record 26 of Set 10 | vila franca do campo
# Processing Record 27 of Set 10 | luanda
# Processing Record 28 of Set 10 | belyy yar
# Processing Record 29 of Set 10 | mahalapye
# Processing Record 30 of Set 10 | marsh harbour
# Processing Record 31 of Set 10 | nikolskoye
# Processing Record 32 of Set 10 | shar
# Processing Record 33 of Set 10 | beringovskiy
# Processing Record 34 of Set 10 | cabinda
# Processing Record 35 of Set 10 | clyde river
# Processing Record 36 of Set 10 | dom pedro
# Processing Record 37 of Set 10 | beloha
# Processing Record 38 of Set 10 | kuliyapitiya
# Processing Record 39 of Set 10 | ihosy
# Processing Record 40 of Set 10 | alta floresta
# Processing Record 41 of Set 10 | turochak
# Processing Record 42 of Set 10 | bima
# Processing Record 43 of Set 10 | yar-sale
# Processing Record 44 of Set 10 | takoradi
# Processing Record 45 of Set 10 | carballo
# Processing Record 46 of Set 10 | high level
# Processing Record 47 of Set 10 | simao
# Processing Record 48 of Set 10 | kapustin yar
# Processing Record 49 of Set 10 | shingu
# Processing Record 50 of Set 10 | santiago
# Processing Record 1 of Set 11 | esperance
# Processing Record 2 of Set 11 | arequipa
# Processing Record 3 of Set 11 | flin flon
# Processing Record 4 of Set 11 | tongliao
# Processing Record 5 of Set 11 | loukhi
# Processing Record 6 of Set 11 | menidion
# City not found. Skipping...
# Processing Record 7 of Set 11 | tricase
# Processing Record 8 of Set 11 | fukue
# Processing Record 9 of Set 11 | namatanai
# Processing Record 10 of Set 11 | soyo
# Processing Record 11 of Set 11 | chico
# Processing Record 12 of Set 11 | cururupu
# Processing Record 13 of Set 11 | hualmay
# Processing Record 14 of Set 11 | sokoni
# Processing Record 15 of Set 11 | banjarmasin
# Processing Record 16 of Set 11 | broken hill
# Processing Record 17 of Set 11 | ko samui
# Processing Record 18 of Set 11 | ust-tsilma
# Processing Record 19 of Set 11 | warwick
# Processing Record 20 of Set 11 | uwayl
# City not found. Skipping...
# Processing Record 21 of Set 11 | saint-augustin
# Processing Record 22 of Set 11 | kualakapuas
# Processing Record 23 of Set 11 | morondava
# Processing Record 24 of Set 11 | taldan
# Processing Record 25 of Set 11 | pueblo nuevo
# Processing Record 26 of Set 11 | jalingo
# Processing Record 27 of Set 11 | muhos
# Processing Record 28 of Set 11 | tiarei
# Processing Record 29 of Set 11 | lillooet
# Processing Record 30 of Set 11 | sao joao de pirabas
# Processing Record 31 of Set 11 | coos bay
# Processing Record 32 of Set 11 | lata
# Processing Record 33 of Set 11 | danielskuil
# Processing Record 34 of Set 11 | vestmannaeyjar
# Processing Record 35 of Set 11 | westport
# Processing Record 36 of Set 11 | san luis
# Processing Record 37 of Set 11 | mogocha
# Processing Record 38 of Set 11 | ayia marina
# Processing Record 39 of Set 11 | ghansor
# Processing Record 40 of Set 11 | asfi
# Processing Record 41 of Set 11 | svobodnyy
# Processing Record 42 of Set 11 | merauke
# Processing Record 43 of Set 11 | evensk
# Processing Record 44 of Set 11 | port hawkesbury
# Processing Record 45 of Set 11 | cavan
# Processing Record 46 of Set 11 | waddan
# Processing Record 47 of Set 11 | dawei
# Processing Record 48 of Set 11 | denison
# Processing Record 49 of Set 11 | ulladulla
# Processing Record 50 of Set 11 | jega
# Processing Record 1 of Set 12 | caete
# Processing Record 2 of Set 12 | winnetka
# Processing Record 3 of Set 12 | nemuro
# Processing Record 4 of Set 12 | lazaro cardenas
# Processing Record 5 of Set 12 | bereznik
# Processing Record 6 of Set 12 | pekan
# Processing Record 7 of Set 12 | bukama
# Processing Record 8 of Set 12 | presidencia roque saenz pena
# Processing Record 9 of Set 12 | rocha
# Processing Record 10 of Set 12 | port hardy
# Processing Record 11 of Set 12 | weymouth
# Processing Record 12 of Set 12 | neryungri
# Processing Record 13 of Set 12 | marystown
# Processing Record 14 of Set 12 | champerico
# Processing Record 15 of Set 12 | kelvington
# Processing Record 16 of Set 12 | sabang
# Processing Record 17 of Set 12 | prestonpans
# Processing Record 18 of Set 12 | sinop
# Processing Record 19 of Set 12 | balakhninskiy
# Processing Record 20 of Set 12 | plettenberg bay
# Processing Record 21 of Set 12 | de aar
# Processing Record 22 of Set 12 | coria
# Processing Record 23 of Set 12 | kuressaare
# Processing Record 24 of Set 12 | goderich
# Processing Record 25 of Set 12 | paamiut
# Processing Record 26 of Set 12 | cortez
# Processing Record 27 of Set 12 | viligili
# City not found. Skipping...
# Processing Record 28 of Set 12 | mergui
# City not found. Skipping...
# Processing Record 29 of Set 12 | araioses
# Processing Record 30 of Set 12 | pangnirtung
# Processing Record 31 of Set 12 | rawson
# Processing Record 32 of Set 12 | polunochnoye
# Processing Record 33 of Set 12 | bathurst
# Processing Record 34 of Set 12 | togul
# Processing Record 35 of Set 12 | nisia floresta
# Processing Record 36 of Set 12 | kabanjahe
# Processing Record 37 of Set 12 | codrington
# Processing Record 38 of Set 12 | mujiayingzi
# Processing Record 39 of Set 12 | paita
# Processing Record 40 of Set 12 | tabuk
# Processing Record 41 of Set 12 | manaus
# Processing Record 42 of Set 12 | severo-yeniseyskiy
# Processing Record 43 of Set 12 | ravar
# Processing Record 44 of Set 12 | paytug
# City not found. Skipping...
# Processing Record 45 of Set 12 | sumbe
# Processing Record 46 of Set 12 | anchorage
# Processing Record 47 of Set 12 | asekeyevo
# Processing Record 48 of Set 12 | siparia
# Processing Record 49 of Set 12 | san cristobal
# Processing Record 50 of Set 12 | college
# Processing Record 1 of Set 13 | gisborne
# Processing Record 2 of Set 13 | amapa
# Processing Record 3 of Set 13 | gat
# Processing Record 4 of Set 13 | tautira
# Processing Record 5 of Set 13 | saint-louis
# Processing Record 6 of Set 13 | gladstone
# Processing Record 7 of Set 13 | pokosnoye
# Processing Record 8 of Set 13 | ondjiva
# Processing Record 9 of Set 13 | buraydah
# Processing Record 10 of Set 13 | santa isabel do rio negro
# Processing Record 11 of Set 13 | bonthe
# Processing Record 12 of Set 13 | vanimo
# Processing Record 13 of Set 13 | oranjemund
# Processing Record 14 of Set 13 | eldorado
# Processing Record 15 of Set 13 | vagur
# Processing Record 16 of Set 13 | krasnogorsk
# Processing Record 17 of Set 13 | pangody
# Processing Record 18 of Set 13 | miramar
# Processing Record 19 of Set 13 | puebloviejo
# Processing Record 20 of Set 13 | ayr
# Processing Record 21 of Set 13 | daloa
# Processing Record 22 of Set 13 | kant
# Processing Record 23 of Set 13 | deputatskiy
# Processing Record 24 of Set 13 | esfahan
# Processing Record 25 of Set 13 | horadiz
# Processing Record 26 of Set 13 | terra santa
# Processing Record 27 of Set 13 | vanavara
# Processing Record 28 of Set 13 | jardim
# Processing Record 29 of Set 13 | saint pete beach
# Processing Record 30 of Set 13 | barawe
# City not found. Skipping...
# Processing Record 31 of Set 13 | viransehir
# Processing Record 32 of Set 13 | sebastian
# Processing Record 33 of Set 13 | hay river
# Processing Record 34 of Set 13 | lebu
# Processing Record 35 of Set 13 | hohhot
# Processing Record 36 of Set 13 | djenne
# Processing Record 37 of Set 13 | sabla
# Processing Record 38 of Set 13 | malanje
# Processing Record 39 of Set 13 | esna
# Processing Record 40 of Set 13 | antofagasta
# Processing Record 41 of Set 13 | slave lake
# Processing Record 42 of Set 13 | kysyl-syr
# Processing Record 43 of Set 13 | viedma
# Processing Record 44 of Set 13 | erie
# Processing Record 45 of Set 13 | guayape
# Processing Record 46 of Set 13 | santa isabel
# Processing Record 47 of Set 13 | khandyga
# Processing Record 48 of Set 13 | bur gabo
# City not found. Skipping...
# Processing Record 49 of Set 13 | kankon
# Processing Record 50 of Set 13 | omboue
# Processing Record 1 of Set 14 | nouakchott
# Processing Record 2 of Set 14 | deda
# Processing Record 3 of Set 14 | xinmin
# Processing Record 4 of Set 14 | assens
# Processing Record 5 of Set 14 | fuzhou
# Processing Record 6 of Set 14 | sorland
# Processing Record 7 of Set 14 | biak
# Processing Record 8 of Set 14 | ormara
# Processing Record 9 of Set 14 | khonuu
# City not found. Skipping...
# Processing Record 10 of Set 14 | lavrentiya
# Processing Record 11 of Set 14 | bien hoa
# Processing Record 12 of Set 14 | yumen
# Processing Record 13 of Set 14 | tondano
# Processing Record 14 of Set 14 | eyl
# Processing Record 15 of Set 14 | kotma
# Processing Record 16 of Set 14 | san lawrenz
# Processing Record 17 of Set 14 | gospic
# Processing Record 18 of Set 14 | lolua
# City not found. Skipping...
# Processing Record 19 of Set 14 | alto araguaia
# Processing Record 20 of Set 14 | shuangyang
# Processing Record 21 of Set 14 | vieux-habitants
# Processing Record 22 of Set 14 | tierranueva
# Processing Record 23 of Set 14 | nago
# Processing Record 24 of Set 14 | inhambane
# Processing Record 25 of Set 14 | santa maria
# Processing Record 26 of Set 14 | tomatlan
# Processing Record 27 of Set 14 | blonduos
# City not found. Skipping...
# Processing Record 28 of Set 14 | saint-pierre
# Processing Record 29 of Set 14 | skibbereen
# Processing Record 30 of Set 14 | saint-joseph
# Processing Record 31 of Set 14 | japura
# Processing Record 32 of Set 14 | guantanamo
# Processing Record 33 of Set 14 | cristalina
# Processing Record 34 of Set 14 | manbij
# Processing Record 35 of Set 14 | ilhabela
# Processing Record 36 of Set 14 | solofra
# Processing Record 37 of Set 14 | gigante
# Processing Record 38 of Set 14 | lodja
# Processing Record 39 of Set 14 | oskemen
# Processing Record 40 of Set 14 | nador
# Processing Record 41 of Set 14 | talaya
# Processing Record 42 of Set 14 | mrirt
# City not found. Skipping...
# Processing Record 43 of Set 14 | rongcheng
# Processing Record 44 of Set 14 | amurzet
# Processing Record 45 of Set 14 | monreal
# Processing Record 46 of Set 14 | wulanhaote
# City not found. Skipping...
# Processing Record 47 of Set 14 | massakory
# Processing Record 48 of Set 14 | cockburn harbour
# City not found. Skipping...
# Processing Record 49 of Set 14 | camapua
# Processing Record 50 of Set 14 | iquitos
# Processing Record 1 of Set 15 | sola
# Processing Record 2 of Set 15 | mosquera
# Processing Record 3 of Set 15 | wanning
# Processing Record 4 of Set 15 | sungaipenuh
# Processing Record 5 of Set 15 | murray bridge
# Processing Record 6 of Set 15 | villa carlos paz
# Processing Record 7 of Set 15 | kaohsiung
# Processing Record 8 of Set 15 | oistins
# Processing Record 9 of Set 15 | ankang
# Processing Record 10 of Set 15 | jaca
# Processing Record 11 of Set 15 | ixtapa
# Processing Record 12 of Set 15 | khalandritsa
# City not found. Skipping...
# Processing Record 13 of Set 15 | riverton
# Processing Record 14 of Set 15 | bongandanga
# Processing Record 15 of Set 15 | barbar
# City not found. Skipping...
# Processing Record 16 of Set 15 | niceville
# Processing Record 17 of Set 15 | guarapari
# Processing Record 18 of Set 15 | cervo
# Processing Record 19 of Set 15 | morro bay
# Processing Record 20 of Set 15 | minsk
# Processing Record 21 of Set 15 | serro
# Processing Record 22 of Set 15 | boissevain
# Processing Record 23 of Set 15 | ballangen
# Processing Record 24 of Set 15 | borujerd
# Processing Record 25 of Set 15 | bara
# Processing Record 26 of Set 15 | bargal
# City not found. Skipping...
# Processing Record 27 of Set 15 | kibala
# Processing Record 28 of Set 15 | mackay
# Processing Record 29 of Set 15 | morgaushi
# Processing Record 30 of Set 15 | mayo
# Processing Record 31 of Set 15 | davila
# Processing Record 32 of Set 15 | cozumel
# Processing Record 33 of Set 15 | dauphin
# Processing Record 34 of Set 15 | quilmana
# Processing Record 35 of Set 15 | barabai
# Processing Record 36 of Set 15 | mogadishu
# Processing Record 37 of Set 15 | dwarka
# Processing Record 38 of Set 15 | piacabucu
# Processing Record 39 of Set 15 | grand gaube
# Processing Record 40 of Set 15 | ahipara
# Processing Record 41 of Set 15 | ilulissat
# Processing Record 42 of Set 15 | paracatu
# Processing Record 43 of Set 15 | parkes
# Processing Record 44 of Set 15 | garowe
# Processing Record 45 of Set 15 | jazzin
# City not found. Skipping...
# Processing Record 46 of Set 15 | sampit
# -------------------------
# Data Retrieval Complete
# -------------------------

# %%
len(city_data)
# Out:
# 696

# %%
#Convert the array of dictionaries to a pandas DataFrame
city_data_df = pd.DataFrame(city_data)
city_data_df.head()
# Out:
#          City      Lat       Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0    Smithers  54.7804 -127.1743      7.12        85          90        0.00
# 1       Kapaa  22.0752 -159.3190     73.72        77          90        4.00
# 2       Warri   5.5167    5.7500     79.68        51           3        6.40
# 3     Erenhot  43.6475  111.9767     18.16        62           0        7.56
# 4  Saint-Paul -21.0096   55.2707     78.91        96         100        2.13
#
#   Country Weather Description                Date
# 0      CA          light snow  2021-12-21 19:0745
# 1      US          light rain  2021-12-21 19:0746
# 2      NG           clear sky  2021-12-21 19:0746
# 3      CN           clear sky  2021-12-21 19:0746
# 4      RE          light rain  2021-12-21 19:0747

# %%
new_column_order = ["City","Country","Date","Lat","Lng","Max Temp","Humidity","Cloudiness", "Wind Speed","Weather Description"]
city_data_df = city_data_df[new_column_order]
city_data_df
# Out:
#            City Country                Date      Lat       Lng  Max Temp  \
# 0      Smithers      CA  2021-12-21 19:0745  54.7804 -127.1743      7.12
# 1         Kapaa      US  2021-12-21 19:0746  22.0752 -159.3190     73.72
# 2         Warri      NG  2021-12-21 19:0746   5.5167    5.7500     79.68
# 3       Erenhot      CN  2021-12-21 19:0746  43.6475  111.9767     18.16
# 4    Saint-Paul      RE  2021-12-21 19:0747 -21.0096   55.2707     78.91
# ..          ...     ...                 ...      ...       ...       ...
# 691   Ilulissat      GL  2021-12-21 19:2445  69.2167  -51.1000     42.82
# 692    Paracatu      BR  2021-12-21 19:2445 -17.2222  -46.8747     81.59
# 693      Parkes      AU  2021-12-21 19:2446 -33.1333  148.1833     64.35
# 694      Garowe      SO  2021-12-21 19:2446   8.4054   48.4845     72.34
# 695      Sampit      ID  2021-12-21 19:2446  -2.5333  112.9500     73.69
#
#      Humidity  Cloudiness  Wind Speed Weather Description
# 0          85          90        0.00          light snow
# 1          77          90        4.00          light rain
# 2          51           3        6.40           clear sky
# 3          62           0        7.56           clear sky
# 4          96         100        2.13          light rain
# ..        ...         ...         ...                 ...
# 691        31          40       24.16    scattered clouds
# 692        61          59        3.96       broken clouds
# 693        62         100        2.15     overcast clouds
# 694        65         100       17.20     overcast clouds
# 695        98         100        0.65     overcast clouds
#
# [696 rows x 10 columns]

# %%
#Create the output file (CSV format)
output_data_file = "WeatherPY_Database.csv"
#Export the city data into a csv
city_data_df.to_csv(output_data_file,index_label = "City_ID")
