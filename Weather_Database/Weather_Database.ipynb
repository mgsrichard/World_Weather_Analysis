# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from citipy import citipy
import requests
from config import weather_api_key
from datetime import datetime
import time
from pprint import pprint

# %%
#Create a set of random latitude and longitude combinations
lats = np.random.uniform(-90.000, 90.000, size = 2000)
lngs = np.random.uniform(-180, 180, size = 2000)
lat_lngs = zip(lats,lngs)
lat_lngs

#Add the latitudes and longitudes to a list
coordinates = list(lat_lngs)
#coordinates

# %%
#Create a list for holding the cities
cities = []
#Identify the nearest city for each coordinate set 
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0],coordinate[1]).city_name
    
    #If city is unique, add it to the city list
    if city not in cities:
        cities.append(city)
        
#Print the city count to confirm sufficient count
len(cities)
# Out:
# 763

# %%
#Starting URL for Weather Map API call
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID="+weather_api_key

#Create an empty list to hold the weather data
city_data = []

#Print the beginning of the logging
print("Beginning Data Retrieval   ")
print("-------------------------")

#Create counters
record_count = 1
set_count = 1


#Loop through the cities and build the city url
for i, city in enumerate(cities):
    
    
    
    #Group cities in sets of 50 for logging purposes (and for not exceeding api limits)
    #if i has no remainder when divided by 50, which means we have completed a set of 50, (% is the operator for modular arithmetic)
    #then increment main counter and increment set counter
    #so this if is executed after the 50th, 100th, etc pass, this is when we sleep for a minute
    if (i % 50 == 0 and i >= 50): 
        set_count += 1
        record_count = 1
        time.sleep(60)

    #Create an endpoint url with each city
    city_url = url + "&q=" + city.replace(" ","+")

    #Log the URL, record, and set numbers and the city
    print(f"Processing Record {record_count} of Set {set_count} | {city}")

    #Add one to the record count
    record_count += 1
    
    try:
        #Parse the JSON and retrieve data
        city_weather = requests.get(city_url).json()
        #Parse out the needed data
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_description = city_weather["weather"][0]["description"]
        #Convert the time to ISO standard
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M%S')
        #append the data into the city_data list
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Current Description": city_description,
                          "Date": city_date})
        
    #if an error is experienced, skip the city    
    except:
        print("City not found. Skipping...")
        pass
    
#Indicate that the Data Loading is complete
print("-------------------------")
print("Data Retrieval Complete")
print("-------------------------")
# Out:
# Beginning Data Retrieval
# -------------------------
# Processing Record 1 of Set 1 | aksarka
# Processing Record 2 of Set 1 | qasigiannguit
# Processing Record 3 of Set 1 | grindavik
# Processing Record 4 of Set 1 | mount gambier
# Processing Record 5 of Set 1 | ponta delgada
# Processing Record 6 of Set 1 | gualaquiza
# Processing Record 7 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 8 of Set 1 | longyearbyen
# Processing Record 9 of Set 1 | airai
# Processing Record 10 of Set 1 | ambulu
# Processing Record 11 of Set 1 | ambilobe
# Processing Record 12 of Set 1 | atuona
# Processing Record 13 of Set 1 | amapa
# Processing Record 14 of Set 1 | new norfolk
# Processing Record 15 of Set 1 | albany
# Processing Record 16 of Set 1 | ushuaia
# Processing Record 17 of Set 1 | barrow
# Processing Record 18 of Set 1 | kedrovyy
# Processing Record 19 of Set 1 | avarua
# Processing Record 20 of Set 1 | rikitea
# Processing Record 21 of Set 1 | gondanglegi
# Processing Record 22 of Set 1 | leningradskiy
# Processing Record 23 of Set 1 | songkhla
# Processing Record 24 of Set 1 | nara
# Processing Record 25 of Set 1 | oliver
# Processing Record 26 of Set 1 | hasaki
# Processing Record 27 of Set 1 | saint-philippe
# Processing Record 28 of Set 1 | walvis bay
# Processing Record 29 of Set 1 | kapaa
# Processing Record 30 of Set 1 | mozarlandia
# Processing Record 31 of Set 1 | barentsburg
# City not found. Skipping...
# Processing Record 32 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 33 of Set 1 | bredasdorp
# Processing Record 34 of Set 1 | latung
# Processing Record 35 of Set 1 | castro
# Processing Record 36 of Set 1 | samana
# Processing Record 37 of Set 1 | kodiak
# Processing Record 38 of Set 1 | cherskiy
# Processing Record 39 of Set 1 | busselton
# Processing Record 40 of Set 1 | chokurdakh
# Processing Record 41 of Set 1 | miandrivazo
# Processing Record 42 of Set 1 | waipawa
# Processing Record 43 of Set 1 | nikolskoye
# Processing Record 44 of Set 1 | prescott valley
# Processing Record 45 of Set 1 | hilo
# Processing Record 46 of Set 1 | sakakah
# Processing Record 47 of Set 1 | bluff
# Processing Record 48 of Set 1 | thompson
# Processing Record 49 of Set 1 | namibe
# Processing Record 50 of Set 1 | talnakh
# Processing Record 1 of Set 2 | hobart
# Processing Record 2 of Set 2 | nizhneyansk
# City not found. Skipping...
# Processing Record 3 of Set 2 | aklavik
# Processing Record 4 of Set 2 | jacareacanga
# Processing Record 5 of Set 2 | sumbe
# Processing Record 6 of Set 2 | vaini
# Processing Record 7 of Set 2 | kosel
# Processing Record 8 of Set 2 | champerico
# Processing Record 9 of Set 2 | mill valley
# Processing Record 10 of Set 2 | umm kaddadah
# Processing Record 11 of Set 2 | atbasar
# Processing Record 12 of Set 2 | mataura
# Processing Record 13 of Set 2 | okandja
# City not found. Skipping...
# Processing Record 14 of Set 2 | petropavlovsk-kamchatskiy
# Processing Record 15 of Set 2 | hirara
# Processing Record 16 of Set 2 | bay roberts
# Processing Record 17 of Set 2 | chuy
# Processing Record 18 of Set 2 | ponta do sol
# Processing Record 19 of Set 2 | salalah
# Processing Record 20 of Set 2 | roald
# Processing Record 21 of Set 2 | provideniya
# Processing Record 22 of Set 2 | lang suan
# Processing Record 23 of Set 2 | cape town
# Processing Record 24 of Set 2 | olavarria
# Processing Record 25 of Set 2 | carnarvon
# Processing Record 26 of Set 2 | nelson bay
# Processing Record 27 of Set 2 | dalby
# Processing Record 28 of Set 2 | marcona
# City not found. Skipping...
# Processing Record 29 of Set 2 | abu samrah
# Processing Record 30 of Set 2 | burgeo
# Processing Record 31 of Set 2 | qaanaaq
# Processing Record 32 of Set 2 | saleaula
# City not found. Skipping...
# Processing Record 33 of Set 2 | mar del plata
# Processing Record 34 of Set 2 | lompoc
# Processing Record 35 of Set 2 | khatanga
# Processing Record 36 of Set 2 | coquimbo
# Processing Record 37 of Set 2 | hermanus
# Processing Record 38 of Set 2 | ahipara
# Processing Record 39 of Set 2 | lufilufi
# Processing Record 40 of Set 2 | labuhan
# Processing Record 41 of Set 2 | punta arenas
# Processing Record 42 of Set 2 | kurilsk
# Processing Record 43 of Set 2 | puerto ayora
# Processing Record 44 of Set 2 | mishelevka
# Processing Record 45 of Set 2 | san rafael
# Processing Record 46 of Set 2 | krasnoselkup
# Processing Record 47 of Set 2 | kuliyapitiya
# Processing Record 48 of Set 2 | novikovo
# Processing Record 49 of Set 2 | kargil
# Processing Record 50 of Set 2 | guerrero negro
# Processing Record 1 of Set 3 | galbshtadt
# Processing Record 2 of Set 3 | dikson
# Processing Record 3 of Set 3 | jamestown
# Processing Record 4 of Set 3 | iqaluit
# Processing Record 5 of Set 3 | mamlyutka
# Processing Record 6 of Set 3 | georgetown
# Processing Record 7 of Set 3 | palmer
# Processing Record 8 of Set 3 | havre-saint-pierre
# Processing Record 9 of Set 3 | kungurtug
# Processing Record 10 of Set 3 | shimoda
# Processing Record 11 of Set 3 | olafsvik
# Processing Record 12 of Set 3 | huarmey
# Processing Record 13 of Set 3 | cabo san lucas
# Processing Record 14 of Set 3 | qaqortoq
# Processing Record 15 of Set 3 | ossora
# Processing Record 16 of Set 3 | bolshaya chernigovka
# City not found. Skipping...
# Processing Record 17 of Set 3 | aquiraz
# Processing Record 18 of Set 3 | stromness
# Processing Record 19 of Set 3 | ostrovnoy
# Processing Record 20 of Set 3 | rincon
# Processing Record 21 of Set 3 | butaritari
# Processing Record 22 of Set 3 | mogadishu
# Processing Record 23 of Set 3 | sorong
# Processing Record 24 of Set 3 | souillac
# Processing Record 25 of Set 3 | tessalit
# Processing Record 26 of Set 3 | tiksi
# Processing Record 27 of Set 3 | pevek
# Processing Record 28 of Set 3 | umea
# Processing Record 29 of Set 3 | port alfred
# Processing Record 30 of Set 3 | ferme-neuve
# Processing Record 31 of Set 3 | xining
# Processing Record 32 of Set 3 | bengkulu
# Processing Record 33 of Set 3 | los llanos de aridane
# Processing Record 34 of Set 3 | olinda
# Processing Record 35 of Set 3 | klaksvik
# Processing Record 36 of Set 3 | bethel
# Processing Record 37 of Set 3 | belushya guba
# City not found. Skipping...
# Processing Record 38 of Set 3 | manta
# Processing Record 39 of Set 3 | kalmunai
# Processing Record 40 of Set 3 | abbotsford
# Processing Record 41 of Set 3 | tumannyy
# City not found. Skipping...
# Processing Record 42 of Set 3 | grand river south east
# City not found. Skipping...
# Processing Record 43 of Set 3 | luderitz
# Processing Record 44 of Set 3 | domoni
# Processing Record 45 of Set 3 | diego de almagro
# Processing Record 46 of Set 3 | praxedis guerrero
# Processing Record 47 of Set 3 | vaitupu
# City not found. Skipping...
# Processing Record 48 of Set 3 | tuktoyaktuk
# Processing Record 49 of Set 3 | belaya gora
# Processing Record 50 of Set 3 | asosa
# Processing Record 1 of Set 4 | mys shmidta
# City not found. Skipping...
# Processing Record 2 of Set 4 | lebu
# Processing Record 3 of Set 4 | conceicao do araguaia
# Processing Record 4 of Set 4 | victoria
# Processing Record 5 of Set 4 | marabba
# Processing Record 6 of Set 4 | saskylakh
# Processing Record 7 of Set 4 | komsomolskiy
# Processing Record 8 of Set 4 | la palma
# Processing Record 9 of Set 4 | campbell river
# Processing Record 10 of Set 4 | lindenwold
# Processing Record 11 of Set 4 | yellowknife
# Processing Record 12 of Set 4 | plettenberg bay
# Processing Record 13 of Set 4 | vao
# Processing Record 14 of Set 4 | nabire
# Processing Record 15 of Set 4 | angoche
# Processing Record 16 of Set 4 | hami
# Processing Record 17 of Set 4 | flinders
# Processing Record 18 of Set 4 | formoso do araguaia
# City not found. Skipping...
# Processing Record 19 of Set 4 | tasiilaq
# Processing Record 20 of Set 4 | mukdahan
# Processing Record 21 of Set 4 | san patricio
# Processing Record 22 of Set 4 | bambous virieux
# Processing Record 23 of Set 4 | poli
# Processing Record 24 of Set 4 | nsunga
# Processing Record 25 of Set 4 | touros
# Processing Record 26 of Set 4 | solnechnyy
# Processing Record 27 of Set 4 | kyren
# Processing Record 28 of Set 4 | bezhetsk
# Processing Record 29 of Set 4 | terrace bay
# Processing Record 30 of Set 4 | srednekolymsk
# Processing Record 31 of Set 4 | port elizabeth
# Processing Record 32 of Set 4 | mataram
# Processing Record 33 of Set 4 | vrangel
# Processing Record 34 of Set 4 | akyab
# Processing Record 35 of Set 4 | ndjole
# Processing Record 36 of Set 4 | sinnamary
# Processing Record 37 of Set 4 | arraial do cabo
# Processing Record 38 of Set 4 | mahebourg
# Processing Record 39 of Set 4 | dharchula
# Processing Record 40 of Set 4 | mokhotlong
# Processing Record 41 of Set 4 | fortuna
# Processing Record 42 of Set 4 | carauari
# Processing Record 43 of Set 4 | hithadhoo
# Processing Record 44 of Set 4 | benjamin constant
# Processing Record 45 of Set 4 | saldanha
# Processing Record 46 of Set 4 | coihaique
# Processing Record 47 of Set 4 | bogomila
# Processing Record 48 of Set 4 | ukiah
# Processing Record 49 of Set 4 | margate
# Processing Record 50 of Set 4 | kloulklubed
# Processing Record 1 of Set 5 | pangnirtung
# Processing Record 2 of Set 5 | kamaishi
# Processing Record 3 of Set 5 | shelburne
# Processing Record 4 of Set 5 | tawkar
# City not found. Skipping...
# Processing Record 5 of Set 5 | aksha
# Processing Record 6 of Set 5 | semnan
# Processing Record 7 of Set 5 | canton
# Processing Record 8 of Set 5 | lazaro cardenas
# Processing Record 9 of Set 5 | ribeira grande
# Processing Record 10 of Set 5 | gao
# Processing Record 11 of Set 5 | kanniyakumari
# Processing Record 12 of Set 5 | tual
# Processing Record 13 of Set 5 | muros
# Processing Record 14 of Set 5 | anadyr
# Processing Record 15 of Set 5 | geraldton
# Processing Record 16 of Set 5 | jamuria
# Processing Record 17 of Set 5 | kavaratti
# Processing Record 18 of Set 5 | lethem
# Processing Record 19 of Set 5 | nemuro
# Processing Record 20 of Set 5 | puerto madryn
# Processing Record 21 of Set 5 | deputatskiy
# Processing Record 22 of Set 5 | lavrentiya
# Processing Record 23 of Set 5 | mehamn
# Processing Record 24 of Set 5 | veydelevka
# Processing Record 25 of Set 5 | kaitangata
# Processing Record 26 of Set 5 | dingle
# Processing Record 27 of Set 5 | portland
# Processing Record 28 of Set 5 | sotouboua
# Processing Record 29 of Set 5 | katsuura
# Processing Record 30 of Set 5 | lagoa
# Processing Record 31 of Set 5 | mount isa
# Processing Record 32 of Set 5 | panzhihua
# Processing Record 33 of Set 5 | binabalian
# Processing Record 34 of Set 5 | morro bay
# Processing Record 35 of Set 5 | ghanzi
# Processing Record 36 of Set 5 | kruisfontein
# Processing Record 37 of Set 5 | sentyabrskiy
# City not found. Skipping...
# Processing Record 38 of Set 5 | whitehorse
# Processing Record 39 of Set 5 | pathein
# Processing Record 40 of Set 5 | puerto escondido
# Processing Record 41 of Set 5 | meulaboh
# Processing Record 42 of Set 5 | sataua
# City not found. Skipping...
# Processing Record 43 of Set 5 | vyshneve
# Processing Record 44 of Set 5 | pokhara
# Processing Record 45 of Set 5 | dhidhdhoo
# Processing Record 46 of Set 5 | polo
# Processing Record 47 of Set 5 | bhadrachalam
# Processing Record 48 of Set 5 | arak
# Processing Record 49 of Set 5 | slave lake
# Processing Record 50 of Set 5 | narsaq
# Processing Record 1 of Set 6 | tigil
# Processing Record 2 of Set 6 | naze
# Processing Record 3 of Set 6 | mtwara
# Processing Record 4 of Set 6 | agucadoura
# Processing Record 5 of Set 6 | menongue
# Processing Record 6 of Set 6 | jatai
# Processing Record 7 of Set 6 | centralia
# Processing Record 8 of Set 6 | yar-sale
# Processing Record 9 of Set 6 | yenagoa
# Processing Record 10 of Set 6 | viedma
# Processing Record 11 of Set 6 | sento se
# City not found. Skipping...
# Processing Record 12 of Set 6 | maragogi
# Processing Record 13 of Set 6 | caucaia
# Processing Record 14 of Set 6 | oriximina
# Processing Record 15 of Set 6 | khuzhir
# Processing Record 16 of Set 6 | rio gallegos
# Processing Record 17 of Set 6 | sohag
# Processing Record 18 of Set 6 | hofn
# Processing Record 19 of Set 6 | zhaotong
# Processing Record 20 of Set 6 | xifeng
# Processing Record 21 of Set 6 | miranda
# Processing Record 22 of Set 6 | sharan
# Processing Record 23 of Set 6 | codrington
# Processing Record 24 of Set 6 | kainantu
# Processing Record 25 of Set 6 | poyarkovo
# Processing Record 26 of Set 6 | gberia fotombu
# Processing Record 27 of Set 6 | esperance
# Processing Record 28 of Set 6 | chara
# Processing Record 29 of Set 6 | cortez
# Processing Record 30 of Set 6 | atkarsk
# Processing Record 31 of Set 6 | jalu
# Processing Record 32 of Set 6 | flin flon
# Processing Record 33 of Set 6 | gazojak
# Processing Record 34 of Set 6 | yamada
# Processing Record 35 of Set 6 | myitkyina
# Processing Record 36 of Set 6 | pobe
# Processing Record 37 of Set 6 | guadalupe victoria
# Processing Record 38 of Set 6 | bilibino
# Processing Record 39 of Set 6 | cookeville
# Processing Record 40 of Set 6 | attawapiskat
# City not found. Skipping...
# Processing Record 41 of Set 6 | mogochin
# City not found. Skipping...
# Processing Record 42 of Set 6 | sur
# Processing Record 43 of Set 6 | fairbanks
# Processing Record 44 of Set 6 | east london
# Processing Record 45 of Set 6 | langsa
# Processing Record 46 of Set 6 | faanui
# Processing Record 47 of Set 6 | bolivar
# Processing Record 48 of Set 6 | mayo
# Processing Record 49 of Set 6 | beyneu
# Processing Record 50 of Set 6 | khorol
# Processing Record 1 of Set 7 | chegem
# Processing Record 2 of Set 7 | wanning
# Processing Record 3 of Set 7 | porosozero
# Processing Record 4 of Set 7 | adrar
# Processing Record 5 of Set 7 | vardo
# Processing Record 6 of Set 7 | kavieng
# Processing Record 7 of Set 7 | goure
# Processing Record 8 of Set 7 | hanahan
# Processing Record 9 of Set 7 | le mars
# Processing Record 10 of Set 7 | kankon
# Processing Record 11 of Set 7 | sipoo
# Processing Record 12 of Set 7 | pacific grove
# Processing Record 13 of Set 7 | auki
# Processing Record 14 of Set 7 | erenhot
# Processing Record 15 of Set 7 | sioux lookout
# Processing Record 16 of Set 7 | yeppoon
# Processing Record 17 of Set 7 | sicamous
# Processing Record 18 of Set 7 | dunedin
# Processing Record 19 of Set 7 | severo-kurilsk
# Processing Record 20 of Set 7 | bima
# Processing Record 21 of Set 7 | palabuhanratu
# City not found. Skipping...
# Processing Record 22 of Set 7 | chachapoyas
# Processing Record 23 of Set 7 | suileng
# Processing Record 24 of Set 7 | upernavik
# Processing Record 25 of Set 7 | grand gaube
# Processing Record 26 of Set 7 | tommot
# Processing Record 27 of Set 7 | hamilton
# Processing Record 28 of Set 7 | doka
# Processing Record 29 of Set 7 | carballo
# Processing Record 30 of Set 7 | hanna
# Processing Record 31 of Set 7 | tevaitoa
# Processing Record 32 of Set 7 | avera
# Processing Record 33 of Set 7 | kabinda
# Processing Record 34 of Set 7 | bowen
# Processing Record 35 of Set 7 | indian head
# Processing Record 36 of Set 7 | bhakkar
# Processing Record 37 of Set 7 | itarema
# Processing Record 38 of Set 7 | kokologo
# Processing Record 39 of Set 7 | khonsa
# Processing Record 40 of Set 7 | charters towers
# Processing Record 41 of Set 7 | constitucion
# Processing Record 42 of Set 7 | antofagasta
# Processing Record 43 of Set 7 | san cristobal
# Processing Record 44 of Set 7 | pirai
# Processing Record 45 of Set 7 | beringovskiy
# Processing Record 46 of Set 7 | thinadhoo
# Processing Record 47 of Set 7 | ilulissat
# Processing Record 48 of Set 7 | port blair
# Processing Record 49 of Set 7 | koumac
# Processing Record 50 of Set 7 | bandarbeyla
# Processing Record 1 of Set 8 | sisimiut
# Processing Record 2 of Set 8 | natal
# Processing Record 3 of Set 8 | ancud
# Processing Record 4 of Set 8 | nome
# Processing Record 5 of Set 8 | seguela
# Processing Record 6 of Set 8 | beloha
# Processing Record 7 of Set 8 | doctor pedro p. pena
# City not found. Skipping...
# Processing Record 8 of Set 8 | tsiroanomandidy
# Processing Record 9 of Set 8 | el tocuyo
# Processing Record 10 of Set 8 | poya
# Processing Record 11 of Set 8 | amderma
# City not found. Skipping...
# Processing Record 12 of Set 8 | poum
# Processing Record 13 of Set 8 | te anau
# Processing Record 14 of Set 8 | karauzyak
# City not found. Skipping...
# Processing Record 15 of Set 8 | independence
# Processing Record 16 of Set 8 | domat
# Processing Record 17 of Set 8 | okhotsk
# Processing Record 18 of Set 8 | teseney
# Processing Record 19 of Set 8 | satitoa
# City not found. Skipping...
# Processing Record 20 of Set 8 | puerto colombia
# Processing Record 21 of Set 8 | samusu
# City not found. Skipping...
# Processing Record 22 of Set 8 | lityn
# Processing Record 23 of Set 8 | kapoeta
# Processing Record 24 of Set 8 | nanortalik
# Processing Record 25 of Set 8 | pedro carbo
# Processing Record 26 of Set 8 | sitka
# Processing Record 27 of Set 8 | ketchikan
# Processing Record 28 of Set 8 | bundaberg
# Processing Record 29 of Set 8 | oistins
# Processing Record 30 of Set 8 | bathsheba
# Processing Record 31 of Set 8 | alihe
# Processing Record 32 of Set 8 | kenai
# Processing Record 33 of Set 8 | sampit
# Processing Record 34 of Set 8 | goderich
# Processing Record 35 of Set 8 | nuevo progreso
# Processing Record 36 of Set 8 | lorengau
# Processing Record 37 of Set 8 | clyde river
# Processing Record 38 of Set 8 | khani
# Processing Record 39 of Set 8 | cayenne
# Processing Record 40 of Set 8 | cidreira
# Processing Record 41 of Set 8 | tazovskiy
# Processing Record 42 of Set 8 | svetlogorsk
# Processing Record 43 of Set 8 | bilopillya
# Processing Record 44 of Set 8 | qui nhon
# Processing Record 45 of Set 8 | ferrol
# Processing Record 46 of Set 8 | comodoro rivadavia
# Processing Record 47 of Set 8 | sinkat
# City not found. Skipping...
# Processing Record 48 of Set 8 | meyungs
# City not found. Skipping...
# Processing Record 49 of Set 8 | jizan
# Processing Record 50 of Set 8 | port hardy
# Processing Record 1 of Set 9 | kirakira
# Processing Record 2 of Set 9 | datong
# Processing Record 3 of Set 9 | vila
# Processing Record 4 of Set 9 | juneau
# Processing Record 5 of Set 9 | port keats
# Processing Record 6 of Set 9 | oxelosund
# Processing Record 7 of Set 9 | chapais
# Processing Record 8 of Set 9 | busko-zdroj
# Processing Record 9 of Set 9 | onguday
# Processing Record 10 of Set 9 | kudahuvadhoo
# Processing Record 11 of Set 9 | honiara
# Processing Record 12 of Set 9 | chabahar
# Processing Record 13 of Set 9 | vestmannaeyjar
# Processing Record 14 of Set 9 | princeton
# Processing Record 15 of Set 9 | idrinskoye
# Processing Record 16 of Set 9 | akhnur
# Processing Record 17 of Set 9 | belmonte
# Processing Record 18 of Set 9 | drayton valley
# Processing Record 19 of Set 9 | gat
# Processing Record 20 of Set 9 | colares
# Processing Record 21 of Set 9 | log
# Processing Record 22 of Set 9 | talcahuano
# Processing Record 23 of Set 9 | amuntai
# Processing Record 24 of Set 9 | barkot
# Processing Record 25 of Set 9 | dano
# Processing Record 26 of Set 9 | manzil tamim
# City not found. Skipping...
# Processing Record 27 of Set 9 | lesozavodsk
# Processing Record 28 of Set 9 | mayuge
# Processing Record 29 of Set 9 | pitimbu
# Processing Record 30 of Set 9 | araouane
# Processing Record 31 of Set 9 | high level
# Processing Record 32 of Set 9 | acapulco
# Processing Record 33 of Set 9 | borgosesia
# Processing Record 34 of Set 9 | kieta
# Processing Record 35 of Set 9 | warqla
# City not found. Skipping...
# Processing Record 36 of Set 9 | barcelos
# Processing Record 37 of Set 9 | mecca
# Processing Record 38 of Set 9 | sao felix do xingu
# Processing Record 39 of Set 9 | bargal
# City not found. Skipping...
# Processing Record 40 of Set 9 | capreol
# Processing Record 41 of Set 9 | corner brook
# Processing Record 42 of Set 9 | shache
# Processing Record 43 of Set 9 | gulu
# Processing Record 44 of Set 9 | havelock
# Processing Record 45 of Set 9 | saint-augustin
# Processing Record 46 of Set 9 | samalaeulu
# City not found. Skipping...
# Processing Record 47 of Set 9 | zhuhai
# Processing Record 48 of Set 9 | poltavka
# Processing Record 49 of Set 9 | leh
# Processing Record 50 of Set 9 | america dourada
# Processing Record 1 of Set 10 | bonoua
# Processing Record 2 of Set 10 | lixourion
# Processing Record 3 of Set 10 | apatity
# Processing Record 4 of Set 10 | escanaba
# Processing Record 5 of Set 10 | rocha
# Processing Record 6 of Set 10 | muslyumovo
# Processing Record 7 of Set 10 | shieli
# Processing Record 8 of Set 10 | manthani
# Processing Record 9 of Set 10 | cozumel
# Processing Record 10 of Set 10 | roanoke rapids
# Processing Record 11 of Set 10 | shingu
# Processing Record 12 of Set 10 | tsihombe
# City not found. Skipping...
# Processing Record 13 of Set 10 | merritt island
# Processing Record 14 of Set 10 | mubi
# Processing Record 15 of Set 10 | altay
# Processing Record 16 of Set 10 | rosa zarate
# Processing Record 17 of Set 10 | skaudvile
# Processing Record 18 of Set 10 | kupino
# Processing Record 19 of Set 10 | zeya
# Processing Record 20 of Set 10 | asau
# Processing Record 21 of Set 10 | bilma
# Processing Record 22 of Set 10 | tuatapere
# Processing Record 23 of Set 10 | buon me thuot
# City not found. Skipping...
# Processing Record 24 of Set 10 | kaeo
# Processing Record 25 of Set 10 | yulara
# Processing Record 26 of Set 10 | lasa
# Processing Record 27 of Set 10 | chinsali
# Processing Record 28 of Set 10 | snezhnogorsk
# Processing Record 29 of Set 10 | kamenskoye
# City not found. Skipping...
# Processing Record 30 of Set 10 | marratxi
# Processing Record 31 of Set 10 | saraipali
# Processing Record 32 of Set 10 | cam ranh
# Processing Record 33 of Set 10 | paracuru
# Processing Record 34 of Set 10 | povoa de varzim
# Processing Record 35 of Set 10 | warmbad
# Processing Record 36 of Set 10 | kahului
# Processing Record 37 of Set 10 | kamphaeng phet
# Processing Record 38 of Set 10 | la romana
# Processing Record 39 of Set 10 | tukrah
# Processing Record 40 of Set 10 | kumo
# Processing Record 41 of Set 10 | maniitsoq
# Processing Record 42 of Set 10 | stara zagora
# Processing Record 43 of Set 10 | torbay
# Processing Record 44 of Set 10 | beipiao
# Processing Record 45 of Set 10 | henderson
# Processing Record 46 of Set 10 | pisco
# Processing Record 47 of Set 10 | kannur
# Processing Record 48 of Set 10 | russell
# Processing Record 49 of Set 10 | zheleznodorozhnyy
# Processing Record 50 of Set 10 | strezhevoy
# Processing Record 1 of Set 11 | nicoya
# Processing Record 2 of Set 11 | lafiagi
# Processing Record 3 of Set 11 | kabo
# Processing Record 4 of Set 11 | tabiauea
# City not found. Skipping...
# Processing Record 5 of Set 11 | baillif
# Processing Record 6 of Set 11 | hihifo
# City not found. Skipping...
# Processing Record 7 of Set 11 | banjar
# Processing Record 8 of Set 11 | hualmay
# Processing Record 9 of Set 11 | pochutla
# Processing Record 10 of Set 11 | progreso
# Processing Record 11 of Set 11 | pringsewu
# Processing Record 12 of Set 11 | acarau
# Processing Record 13 of Set 11 | umzimvubu
# City not found. Skipping...
# Processing Record 14 of Set 11 | atar
# Processing Record 15 of Set 11 | cap malheureux
# Processing Record 16 of Set 11 | dzaoudzi
# Processing Record 17 of Set 11 | moranbah
# Processing Record 18 of Set 11 | kalabo
# Processing Record 19 of Set 11 | fatehabad
# Processing Record 20 of Set 11 | itacoatiara
# Processing Record 21 of Set 11 | henties bay
# Processing Record 22 of Set 11 | tarakan
# Processing Record 23 of Set 11 | bintulu
# Processing Record 24 of Set 11 | chitrakonda
# Processing Record 25 of Set 11 | wuwei
# Processing Record 26 of Set 11 | fort nelson
# Processing Record 27 of Set 11 | southern pines
# Processing Record 28 of Set 11 | swan river
# Processing Record 29 of Set 11 | luanda
# Processing Record 30 of Set 11 | noumea
# Processing Record 31 of Set 11 | arlit
# Processing Record 32 of Set 11 | berlevag
# Processing Record 33 of Set 11 | rodino
# Processing Record 34 of Set 11 | norman wells
# Processing Record 35 of Set 11 | juba
# Processing Record 36 of Set 11 | estevan
# Processing Record 37 of Set 11 | saint anthony
# Processing Record 38 of Set 11 | karasjok
# Processing Record 39 of Set 11 | san andres
# Processing Record 40 of Set 11 | mikkeli
# Processing Record 41 of Set 11 | pontes e lacerda
# Processing Record 42 of Set 11 | udachnyy
# Processing Record 43 of Set 11 | atkinson
# Processing Record 44 of Set 11 | pau brasil
# Processing Record 45 of Set 11 | begles
# Processing Record 46 of Set 11 | sarkikaraagac
# Processing Record 47 of Set 11 | alice springs
# Processing Record 48 of Set 11 | vila velha
# Processing Record 49 of Set 11 | baruun-urt
# Processing Record 50 of Set 11 | bara
# Processing Record 1 of Set 12 | caravelas
# Processing Record 2 of Set 12 | bealanana
# Processing Record 3 of Set 12 | lewistown
# Processing Record 4 of Set 12 | cedar city
# Processing Record 5 of Set 12 | praia da vitoria
# Processing Record 6 of Set 12 | manaure
# Processing Record 7 of Set 12 | katherine
# Processing Record 8 of Set 12 | rabo de peixe
# Processing Record 9 of Set 12 | boa vista
# Processing Record 10 of Set 12 | ust-uda
# Processing Record 11 of Set 12 | beirut
# Processing Record 12 of Set 12 | nipawin
# Processing Record 13 of Set 12 | salina cruz
# Processing Record 14 of Set 12 | ruatoria
# City not found. Skipping...
# Processing Record 15 of Set 12 | canala
# Processing Record 16 of Set 12 | marzuq
# Processing Record 17 of Set 12 | tete
# Processing Record 18 of Set 12 | hambantota
# Processing Record 19 of Set 12 | puerto quijarro
# Processing Record 20 of Set 12 | tawnat
# City not found. Skipping...
# Processing Record 21 of Set 12 | soderhamn
# Processing Record 22 of Set 12 | dzhebariki-khaya
# Processing Record 23 of Set 12 | paamiut
# Processing Record 24 of Set 12 | hohenems
# Processing Record 25 of Set 12 | ipueiras
# Processing Record 26 of Set 12 | aykhal
# Processing Record 27 of Set 12 | calvinia
# Processing Record 28 of Set 12 | medveda
# Processing Record 29 of Set 12 | marsa matruh
# Processing Record 30 of Set 12 | bubaque
# Processing Record 31 of Set 12 | riberalta
# Processing Record 32 of Set 12 | samarai
# Processing Record 33 of Set 12 | apollonia
# Processing Record 34 of Set 12 | farsund
# Processing Record 35 of Set 12 | san quintin
# Processing Record 36 of Set 12 | praya
# Processing Record 37 of Set 12 | urumqi
# Processing Record 38 of Set 12 | college
# Processing Record 39 of Set 12 | iquitos
# Processing Record 40 of Set 12 | mvuma
# Processing Record 41 of Set 12 | gravdal
# Processing Record 42 of Set 12 | ostrogozhsk
# Processing Record 43 of Set 12 | vanimo
# Processing Record 44 of Set 12 | polunochnoye
# Processing Record 45 of Set 12 | kostino
# Processing Record 46 of Set 12 | kochki
# Processing Record 47 of Set 12 | acajutla
# Processing Record 48 of Set 12 | port angeles
# Processing Record 49 of Set 12 | erzin
# Processing Record 50 of Set 12 | kinablangan
# Processing Record 1 of Set 13 | karratha
# Processing Record 2 of Set 13 | ambon
# Processing Record 3 of Set 13 | richards bay
# Processing Record 4 of Set 13 | iracoubo
# Processing Record 5 of Set 13 | buala
# Processing Record 6 of Set 13 | vieste
# Processing Record 7 of Set 13 | tutoia
# Processing Record 8 of Set 13 | bavleny
# Processing Record 9 of Set 13 | nava
# Processing Record 10 of Set 13 | bonthe
# Processing Record 11 of Set 13 | aswan
# Processing Record 12 of Set 13 | necochea
# Processing Record 13 of Set 13 | manokwari
# Processing Record 14 of Set 13 | trollhattan
# Processing Record 15 of Set 13 | veraval
# Processing Record 16 of Set 13 | amga
# Processing Record 17 of Set 13 | miles city
# Processing Record 18 of Set 13 | orange
# Processing Record 19 of Set 13 | warri
# Processing Record 20 of Set 13 | tubruq
# City not found. Skipping...
# Processing Record 21 of Set 13 | hienghene
# Processing Record 22 of Set 13 | maceio
# Processing Record 23 of Set 13 | ouargaye
# Processing Record 24 of Set 13 | orlik
# Processing Record 25 of Set 13 | siniscola
# Processing Record 26 of Set 13 | phitsanulok
# Processing Record 27 of Set 13 | ivanovka
# Processing Record 28 of Set 13 | dinsor
# City not found. Skipping...
# Processing Record 29 of Set 13 | mikhaylovsk
# Processing Record 30 of Set 13 | cabedelo
# Processing Record 31 of Set 13 | rawannawi
# City not found. Skipping...
# Processing Record 32 of Set 13 | athabasca
# Processing Record 33 of Set 13 | saint-denis
# Processing Record 34 of Set 13 | port hedland
# Processing Record 35 of Set 13 | deep river
# Processing Record 36 of Set 13 | san policarpo
# Processing Record 37 of Set 13 | trat
# Processing Record 38 of Set 13 | isangel
# Processing Record 39 of Set 13 | kologriv
# Processing Record 40 of Set 13 | chegdomyn
# Processing Record 41 of Set 13 | homer
# Processing Record 42 of Set 13 | nepa nagar
# Processing Record 43 of Set 13 | sungaipenuh
# Processing Record 44 of Set 13 | severnyy
# Processing Record 45 of Set 13 | ankazoabo
# Processing Record 46 of Set 13 | corinto
# Processing Record 47 of Set 13 | katakwi
# Processing Record 48 of Set 13 | weihe
# Processing Record 49 of Set 13 | salinas
# Processing Record 50 of Set 13 | arvika
# Processing Record 1 of Set 14 | harper
# Processing Record 2 of Set 14 | namtsy
# Processing Record 3 of Set 14 | alta
# Processing Record 4 of Set 14 | matay
# Processing Record 5 of Set 14 | bogorodskoye
# Processing Record 6 of Set 14 | zapolyarnyy
# Processing Record 7 of Set 14 | yumen
# Processing Record 8 of Set 14 | matadi
# Processing Record 9 of Set 14 | klyuchi
# Processing Record 10 of Set 14 | ilmajoki
# Processing Record 11 of Set 14 | saint george
# Processing Record 12 of Set 14 | cherepanovo
# Processing Record 13 of Set 14 | ngukurr
# City not found. Skipping...
# Processing Record 14 of Set 14 | turayf
# Processing Record 15 of Set 14 | kamen-rybolov
# Processing Record 16 of Set 14 | nyrob
# Processing Record 17 of Set 14 | usti nad orlici
# Processing Record 18 of Set 14 | paradwip
# City not found. Skipping...
# Processing Record 19 of Set 14 | suntar
# Processing Record 20 of Set 14 | zaozerne
# Processing Record 21 of Set 14 | quelimane
# Processing Record 22 of Set 14 | descalvado
# Processing Record 23 of Set 14 | bezhanitsy
# Processing Record 24 of Set 14 | majene
# Processing Record 25 of Set 14 | broome
# Processing Record 26 of Set 14 | satipo
# Processing Record 27 of Set 14 | zaraza
# Processing Record 28 of Set 14 | chicama
# Processing Record 29 of Set 14 | guia lopes da laguna
# Processing Record 30 of Set 14 | sao joao da barra
# Processing Record 31 of Set 14 | gurupi
# Processing Record 32 of Set 14 | labutta
# City not found. Skipping...
# Processing Record 33 of Set 14 | braganca
# Processing Record 34 of Set 14 | paysandu
# Processing Record 35 of Set 14 | gasa
# Processing Record 36 of Set 14 | phan rang
# City not found. Skipping...
# Processing Record 37 of Set 14 | manzanillo
# Processing Record 38 of Set 14 | eureka
# Processing Record 39 of Set 14 | bengkalis
# City not found. Skipping...
# Processing Record 40 of Set 14 | kastamonu
# Processing Record 41 of Set 14 | saint-pierre
# Processing Record 42 of Set 14 | dubbo
# Processing Record 43 of Set 14 | fushun
# Processing Record 44 of Set 14 | port lincoln
# Processing Record 45 of Set 14 | bosaso
# Processing Record 46 of Set 14 | tsivilsk
# Processing Record 47 of Set 14 | utinga
# Processing Record 48 of Set 14 | vanavara
# Processing Record 49 of Set 14 | plymouth
# Processing Record 50 of Set 14 | setermoen
# Processing Record 1 of Set 15 | barabai
# Processing Record 2 of Set 15 | tilichiki
# Processing Record 3 of Set 15 | anito
# Processing Record 4 of Set 15 | haftoni
# Processing Record 5 of Set 15 | abilene
# Processing Record 6 of Set 15 | rawson
# Processing Record 7 of Set 15 | belvedere marittimo
# Processing Record 8 of Set 15 | christchurch
# Processing Record 9 of Set 15 | chagda
# City not found. Skipping...
# Processing Record 10 of Set 15 | verkh-suetka
# Processing Record 11 of Set 15 | pangoa
# Processing Record 12 of Set 15 | pryshyb
# Processing Record 13 of Set 15 | victor harbor
# Processing Record 14 of Set 15 | tessaoua
# Processing Record 15 of Set 15 | fallon
# Processing Record 16 of Set 15 | sorvag
# City not found. Skipping...
# Processing Record 17 of Set 15 | muromtsevo
# Processing Record 18 of Set 15 | neustadt
# Processing Record 19 of Set 15 | nizhnevartovsk
# Processing Record 20 of Set 15 | asyut
# Processing Record 21 of Set 15 | adzope
# Processing Record 22 of Set 15 | ksenyevka
# City not found. Skipping...
# Processing Record 23 of Set 15 | shouguang
# Processing Record 24 of Set 15 | price
# Processing Record 25 of Set 15 | damoh
# Processing Record 26 of Set 15 | morondava
# Processing Record 27 of Set 15 | carutapera
# Processing Record 28 of Set 15 | anloga
# Processing Record 29 of Set 15 | raudeberg
# Processing Record 30 of Set 15 | bendigo
# Processing Record 31 of Set 15 | hashtrud
# Processing Record 32 of Set 15 | zyryanovskiy
# City not found. Skipping...
# Processing Record 33 of Set 15 | kaniama
# Processing Record 34 of Set 15 | mutsamudu
# City not found. Skipping...
# Processing Record 35 of Set 15 | leshukonskoye
# Processing Record 36 of Set 15 | dannenberg
# Processing Record 37 of Set 15 | aubenas
# Processing Record 38 of Set 15 | manacapuru
# Processing Record 39 of Set 15 | eskasem
# City not found. Skipping...
# Processing Record 40 of Set 15 | xochihuehuetlan
# Processing Record 41 of Set 15 | galiwinku
# City not found. Skipping...
# Processing Record 42 of Set 15 | lulindi
# Processing Record 43 of Set 15 | egvekinot
# Processing Record 44 of Set 15 | svetlyy
# Processing Record 45 of Set 15 | vila franca do campo
# Processing Record 46 of Set 15 | kant
# Processing Record 47 of Set 15 | harnosand
# Processing Record 48 of Set 15 | laguna
# Processing Record 49 of Set 15 | taltal
# Processing Record 50 of Set 15 | ulladulla
# Processing Record 1 of Set 16 | loreto
# Processing Record 2 of Set 16 | taoudenni
# Processing Record 3 of Set 16 | hervey bay
# Processing Record 4 of Set 16 | puerto maldonado
# Processing Record 5 of Set 16 | watsa
# Processing Record 6 of Set 16 | bataipora
# Processing Record 7 of Set 16 | kitgum
# Processing Record 8 of Set 16 | la ronge
# Processing Record 9 of Set 16 | tahoua
# Processing Record 10 of Set 16 | kamenka
# Processing Record 11 of Set 16 | salinopolis
# Processing Record 12 of Set 16 | tagusao
# Processing Record 13 of Set 16 | artvin
# -------------------------
# Data Retrieval Complete
# -------------------------

# %%
len(city_data)
# Out:
# 708

# %%
#Convert the array of dictionaries to a pandas DataFrame
city_data_df = pd.DataFrame(city_data)
city_data_df.head()
# Out:
#             City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0        Aksarka  66.5606   67.7975      8.08        96         100
# 1  Qasigiannguit  68.8193  -51.1922     39.45        51          96
# 2      Grindavik  63.8424  -22.4338     36.07        87          90
# 3  Mount Gambier -37.8333  140.7667     48.97        89          72
# 4  Ponta Delgada  37.7333  -25.6667     60.49        72          20
#
#    Wind Speed Country Current Description                Date
# 0        7.96      RU          light snow  2021-12-22 15:1032
# 1       20.18      GL     overcast clouds  2021-12-22 15:1032
# 2        8.05      IS     overcast clouds  2021-12-22 15:1032
# 3        4.76      AU       broken clouds  2021-12-22 15:1033
# 4       27.63      PT          few clouds  2021-12-22 15:1033

# %%
new_column_order = ["City","Country","Date","Lat","Lng","Max Temp","Humidity","Cloudiness", "Wind Speed","Current Description"]
city_data_df = city_data_df[new_column_order]
city_data_df
# Out:
#               City Country                Date      Lat       Lng  Max Temp  \
# 0          Aksarka      RU  2021-12-22 15:1032  66.5606   67.7975      8.08
# 1    Qasigiannguit      GL  2021-12-22 15:1032  68.8193  -51.1922     39.45
# 2        Grindavik      IS  2021-12-22 15:1032  63.8424  -22.4338     36.07
# 3    Mount Gambier      AU  2021-12-22 15:1033 -37.8333  140.7667     48.97
# 4    Ponta Delgada      PT  2021-12-22 15:1033  37.7333  -25.6667     60.49
# ..             ...     ...                 ...      ...       ...       ...
# 703         Tahoua      NE  2021-12-22 15:2836  14.8888    5.2692     85.14
# 704        Kamenka      RU  2021-12-22 15:2836  51.3223   42.7678      0.75
# 705    Salinopolis      BR  2021-12-22 15:2837  -0.6136  -47.3561     85.73
# 706        Tagusao      PH  2021-12-22 15:2837   9.1924  117.8141     78.78
# 707         Artvin      TR  2021-12-22 15:2837  41.1667   41.8333     29.48
#
#      Humidity  Cloudiness  Wind Speed Current Description
# 0          96         100        7.96          light snow
# 1          51          96       20.18     overcast clouds
# 2          87          90        8.05     overcast clouds
# 3          89          72        4.76       broken clouds
# 4          72          20       27.63          few clouds
# ..        ...         ...         ...                 ...
# 703        13          54       11.48       broken clouds
# 704        94          97        7.18     overcast clouds
# 705        68          91       14.83     overcast clouds
# 706        85          76        5.61       broken clouds
# 707        97         100        1.77                snow
#
# [708 rows x 10 columns]

# %%
#Create the output file (CSV format)
output_data_file = "WeatherPY_Database.csv"
#Export the city data into a csv
city_data_df.to_csv(output_data_file,index_label = "City_ID")
